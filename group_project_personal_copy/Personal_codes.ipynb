# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
# california_crimes_df = Path("Resources/california_department_of_justice_1998_to_2023.csv")
US_inflation_rates_df = Path("Resources/Inflation_rates_group_project.csv")

# Read School and Student Data File and store into Pandas DataFrames
# california_crimes = pd.read_csv(california_crimes_df)
US_inflation_rates = pd.read_csv(US_inflation_rates_df)
inflation_df = US_inflation_rates
inflation_range = inflation_df.loc[(inflation_df["Year"] > 1979), :]
inflation_range
# Out:
#     Year Inflation Rate YOY, From Previous Dec. Federal Funds Rate  \
# 51  1980                                 12.50%             18.00%
# 52  1981                                  8.90%             12.00%
# 53  1982                                  3.80%              8.50%
# 54  1983                                  3.80%              9.25%
# 55  1984                                  3.90%              8.25%
# 56  1985                                  3.80%              7.75%
# 57  1986                                  1.10%              6.00%
# 58  1987                                  4.40%              6.75%
# 59  1988                                  4.40%              9.75%
# 60  1989                                  4.60%              8.25%
# 61  1990                                  6.10%              7.00%
# 62  1991                                  3.10%              4.00%
# 63  1992                                  2.90%              3.00%
# ...

# %%
x_axis = inflation_df["Year"]
plt.plot(x_axis, inflation_df["Inflation Rate YOY, From Previous Dec."], marker='o', color='r', linewidth=2, label="Inflation Rate")

# %%
x_axis = 
plt.plot(

ax2.plot(x_axis, workable_df['Inflation Rate YOY, From Previous Dec.'], marker='o', color='#1F77B4', linewidth=2, label='Inflation Rate')
